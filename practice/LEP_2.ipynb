# %% [markdown]
# # Lesson End Project: Pandas
#
# ## Problem statement:
#
# Use the dataset __housing_data.csv__ to perform operations using pandas:
#
# ## Steps to be Followed:
#
# 1. Importing the necessary libraries and importing the dataset
# 2. Exploring the dataset
# 3. Getting the correlation between the attributes
# 4. Generating the plot

# %% [markdown]
# ## 1. Importing the Necessary Libraries and Importing the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('housing_data.csv')
df
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %% [markdown]
# ## 2. Exploring the Dataset
#
# - Observe the head and tail of the data
# - Get the basic information using __info()__
# - Get the statistical information using the __describe method()__

# %%
df.head(2)
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %% [markdown]
# __Observation:__
# - There are 81 columns and 5 rows in the dataset.

# %%
df.tail()
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1455        1455       SC60       RL           62     7917   Pave  None
# 1456        1456       SC20       RL           85    13175   Pave  None
# 1457        1457       SC70       RL           66     9042   Pave  None
# 1458        1458       SC20       RL           68     9717   Pave  None
# 1459        1459       SC20       RL           75     9937   Pave  None
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 1455      Reg         Lvl    AllPub  ...        0     No     No          No
# 1456      Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 1457      Reg         Lvl    AllPub  ...        0     No  GdPrv        Shed
# 1458      Reg         Lvl    AllPub  ...        0     No     No          No
# 1459      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# __Observations:__
# - The above code informs about the data type of each column in the dataset, and if there are any null values are present or not.
# - You can observe that the row GarageYrBlt has some null values.
# - Let's get the summary of the null values in the dataset, by column.

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
df.isna().sum().unique()
# Out:
# array([   0, 1369,  872,    1,   81], dtype=int64)

# %%
df['GarageYrBlt'].isnull().sum()
# Out:
# 81

# %% [markdown]
# __Observation:__
# - Let's deal with the null values.
# - Let's fill the null values of the column GarageYrBlt with the column mean.

# %%
df = df.fillna(df['GarageYrBlt'].mean)

# %%
df['GarageYrBlt'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - Let's check for null values again.

# %%
df.isna().sum().unique()
# Out:
# array([0], dtype=int64)

# %% [markdown]
# - Let's check the statistical summary of the dataset.

# %%
df.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %% [markdown]
# __Observations__:
# - The mean lot area is 10516, which can deviate by 9981.
# - Mean value of the houses build is 1971.

# %% [markdown]
# ## 3. Getting the Correlation Between the Attributes
# - Use the __corr()__ method to get the information

# %%
#import seaborn as sns
df1 = df.select_dtypes(int)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   LotFrontage    1460 non-null   int64
#  2   LotArea        1460 non-null   int64
#  3   OverallQual    1460 non-null   int64
#  4   OverallCond    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   MasVnrArea     1460 non-null   int64
#  8   BsmtFinSF1     1460 non-null   int64
#  9   BsmtFinSF2     1460 non-null   int64
#  10  BsmtUnfSF      1460 non-null   int64
#  11  TotalBsmtSF    1460 non-null   int64
#  12  1stFlrSF       1460 non-null   int64
#  13  2ndFlrSF       1460 non-null   int64
#  14  LowQualFinSF   1460 non-null   int64
#  15  GrLivArea      1460 non-null   int64
#  16  BsmtFullBath   1460 non-null   int64
#  17  BsmtHalfBath   1460 non-null   int64
# ...

# %%
df_corr = df1.corr()
df_corr
# Out:
#                Unnamed: 0  LotFrontage   LotArea  OverallQual  OverallCond  \
# Unnamed: 0       1.000000    -0.019761 -0.033226    -0.028365     0.012609
# LotFrontage     -0.019761     1.000000  0.100739     0.176561    -0.053457
# LotArea         -0.033226     0.100739  1.000000     0.105806    -0.005636
# OverallQual     -0.028365     0.176561  0.105806     1.000000    -0.091932
# OverallCond      0.012609    -0.053457 -0.005636    -0.091932     1.000000
# YearBuilt       -0.012713     0.036853  0.014228     0.572323    -0.375983
# YearRemodAdd    -0.021998     0.078686  0.013788     0.550684     0.073741
# MasVnrArea      -0.051071     0.105010  0.103321     0.407252    -0.125694
# BsmtFinSF1      -0.005024     0.076670  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.005968    -0.009312  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.007940     0.160829 -0.002618     0.308159    -0.136841
# ...

# %% [markdown]
# __Observations__:
# - The correlation values were displayed for all the numeric columns of the dataset.

# %%
import seaborn as sns
sns.heatmap(df_corr)
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Generating the Plot
# - Use the __plot()__ method to generate the plot

# %%
df.plot('GarageYrBlt','YearBuilt')
# Out:
# <AxesSubplot: xlabel='GarageYrBlt'>

# %% [markdown]
# __Observations__:
#
# - The above graph depicts the comparison of the years when the house and garages were built.
# - We can observe from the graph that a house that was built close to 1918, had its garage built in the year 2003.
