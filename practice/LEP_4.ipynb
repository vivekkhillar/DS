# %% [markdown]
# # Lesson End Project: Exploratory Data Analysis
#
# ### Problem statement:
#
# Use the dataset **telecom.csv** to perform the exploratory data analysis.
#
# ### Steps to be followed:
#
# 1. Importing the necessary libraries and import the dataset
# 2. Getting the basic information about the dataset and data types
# 3. Plotting various graphs to understand different columns of the dataset
# 4. Detecting outliers using boxplot
# 5. Visualizing the correlation between the various columns of the dataset

# %% [markdown]
# ## Step 1: Importing the Necessary Libraries and Importing the Dataset
# - Import __Pandas__ and __matplotlib__
# - Import the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('telecom.csv')
df
# Out:
#      caseid  age  gender  devicetype  locality  region  calls  sms  data  vas  \
# 0         1    2       1           1         0       2    303  102  1756   27
# 1         2    1       1           1         0       1    370   94  2048   13
# 2         3    0       1           1         1       0    425   95  2147   15
# 3         4    1       1           1         1       1    284   88  1784   23
# 4         5    2       1           0         1       1    419  102  2070   21
# ..      ...  ...     ...         ...       ...     ...    ...  ...   ...  ...
# 995      96    1       0           0         1       1    507  115  1969   14
# 996      97    1       1           1         1       3    277   97  1820   19
# 997      98    3       1           0         1       2     94  102  2470   16
# 998      99    2       0           1         1       1    545  106  2095   17
# 999     100    0       0           0         1       2    471  103  2078   18
#
# ...

# %%
df.shape
# Out:
# (1000, 15)

# %% [markdown]
# ## 2. Getting the Basic Information About the Dataset and Data Types
# - Get first 5 rows of the data using the __head()__ function
# - Get the data types of all the columns and other information using the __info()__ method
# - Check for any missing or null values

# %%
df.head()
# Out:
#    caseid  age  gender  devicetype  locality  region  calls  sms  data  vas  \
# 0       1    2       1           1         0       2    303  102  1756   27
# 1       2    1       1           1         0       1    370   94  2048   13
# 2       3    0       1           1         1       0    425   95  2147   15
# 3       4    1       1           1         1       1    284   88  1784   23
# 4       5    2       1           0         1       1    419  102  2070   21
#
#    network  rcalls  rsms  seconds    amount
# 0       52      60    51    38755  1131.850
# 1       46      74    47    67635  1706.500
# 2       38      85    47    29123   857.885
# 3       52      56    44    25803   825.560
# 4       57      83    51    41156  1067.820

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   caseid      1000 non-null   int64
#  1   age         1000 non-null   int64
#  2   gender      1000 non-null   int64
#  3   devicetype  1000 non-null   int64
#  4   locality    1000 non-null   int64
#  5   region      1000 non-null   int64
#  6   calls       1000 non-null   int64
#  7   sms         1000 non-null   int64
#  8   data        1000 non-null   int64
#  9   vas         1000 non-null   int64
#  10  network     1000 non-null   int64
#  11  rcalls      1000 non-null   int64
#  12  rsms        1000 non-null   int64
#  13  seconds     1000 non-null   int64
#  14  amount      1000 non-null   float64
# dtypes: float64(1), int64(14)
# memory usage: 117.3 KB

# %% [markdown]
# __Observations:__
# - The data type of each column is mentioned.
# - There are no null values in the dataset.

# %%
df.isna().sum()
# Out:
# caseid        0
# age           0
# gender        0
# devicetype    0
# locality      0
# region        0
# calls         0
# sms           0
# data          0
# vas           0
# network       0
# rcalls        0
# rsms          0
# seconds       0
# amount        0
# dtype: int64

# %%
df.tail()
# Out:
#      caseid  age  gender  devicetype  locality  region  calls  sms  data  vas  \
# 995      96    1       0           0         1       1    507  115  1969   14
# 996      97    1       1           1         1       3    277   97  1820   19
# 997      98    3       1           0         1       2     94  102  2470   16
# 998      99    2       0           1         1       1    545  106  2095   17
# 999     100    0       0           0         1       2    471  103  2078   18
#
#      network  rcalls  rsms  seconds    amount
# 995       41     101    57    44653  1260.535
# 996       50      55    48    26328   911.510
# 997       59      18    51    10594   401.030
# 998       45     109    53    46428  1536.485
# 999       47      94    51    62032  1657.740

# %%
df.describe()
# Out:
#             caseid          age       gender   devicetype    locality  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     50.500000     1.531000     0.595000     0.667000     0.61800
# std      28.880514     0.872812     0.491138     0.471522     0.48612
# min       1.000000     0.000000     0.000000     0.000000     0.00000
# 25%      25.750000     1.000000     0.000000     0.000000     0.00000
# 50%      50.500000     2.000000     1.000000     1.000000     1.00000
# 75%      75.250000     2.000000     1.000000     1.000000     1.00000
# max     100.000000     3.000000     1.000000     1.000000     1.00000
#
#             region        calls          sms         data          vas  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.510000   400.128000    99.379000  1996.288000    19.458000
# std       0.864087    99.802967     5.008037   252.092486     5.074247
# ...

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.dtypes
# Out:
# caseid          int64
# age             int64
# gender          int64
# devicetype      int64
# locality        int64
# region          int64
# calls           int64
# sms             int64
# data            int64
# vas             int64
# network         int64
# rcalls          int64
# rsms            int64
# seconds         int64
# amount        float64
# dtype: object

# %% [markdown]
# ## 3. Plotting Various Graphs to Understand Different Columns of the Dataset
# - Visualize the age and the number of seconds in the dataset using the subplot method
# - Get an overview of the relationship between the columns using the pair plot

# %%
plt.figure()
plt.subplot(2, 1, 1)  
plt.hist(df['seconds'])
plt.title('Histogram')
plt.xlabel('Call duration in seconds')
plt.ylabel('Count')
plt.show()

plt.subplot(2, 1, 2)  
plt.scatter(x='amount', y='seconds', data= df)
plt.title('Scatter plot')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# __Observations:__
# - You have got two plots. The first depicts the number of seconds of the calls.
# - The second graph shows the price that was charged for the calls, using a scatterplot.

# %%
cols =['age','region','calls','sms','data','seconds','amount']
sns.pairplot(df[cols])
plt.show()

# %% [markdown]
# __Observations__:
# - The above graph shows the relationship between various features of the dataset.
# - For example, the linear relationship between the number of calls and the amount charged can be clearly made out.

# %% [markdown]
# ## Step 4: Detecting Outliers Using the Boxplot
# - Boxplot helps to visualize the outliers when 2 columns are put in x and y axes

# %%
plt.subplot(2,1,1)
sns.boxplot(x= 'region', y='calls', data=df)
plt.show()

plt.subplot(2,1,2)
sns.boxplot(x ='network', y= 'calls', data=df)
plt.show()

# %% [markdown]
# __Observations:__
# - The outliers for the feature calls when compared with each network and region is illustrated above.

# %% [markdown]
# ### 5. Visualizing the Correlation Between the Various Columns of the Dataset
# - Correlation can be visualized using the __corr()__ method

# %%
sns.heatmap(df.corr())
plt.show()

# winsorization is removes the outliers by replacing them with the nearest non-outlier value

# %% [markdown]
# ### Obervations:
# - The dataset has most interger values with data type int64.
# - It has no null values.
# - Various columns were visualized in the bivariate and multivariate analysis using various graphs.
# - Outliers were detected using the boxplot.
# - The correlation between the variables were found using the __corr()__ method.
