# %% [markdown]
# # Lesson End Project: Matplotlib
#
# ## Problem statement:
#
# Using an array as input to the dataset, generate a scatterplot, a histogram, subplots, and a line plot.
#
# ## Steps to be followed:
#
# 1. Importing the necessary libraries
# 2. Creating an array using a random number array
# 3. Generating a scatterplot
# 4. Generating a histogram
# 5. Generating subplots
# 6. Generating a line plot

# %% [markdown]
# ## Step 1: Importing the Necessary Libraries
# - Import numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Creating Data Using a Random Number Array
# - Use the __random.randn()__ function to generate the array

# %%
data = np.random.randn(100)
data
# Out:
# array([ 0.68417851,  0.14674927,  0.47401163, -0.53188964, -0.27908444,
#        -0.89141183,  0.75742009, -0.73072546, -0.61135063,  1.73858864,
#         0.27096746,  1.24483153, -0.72857416,  0.38154732, -2.24198805,
#         0.95734594, -0.52703724, -0.42324835,  0.85084498, -0.18655295,
#         0.1160094 , -0.88684348,  0.20935851, -0.91255475, -0.88729564,
#         1.13731995,  1.4524388 , -0.87435073,  2.3292549 ,  1.95550317,
#         1.50285341, -0.09852173, -0.96525304, -1.5650735 ,  0.74445453,
#         0.21359399, -0.73485018,  0.62076443, -1.50996354,  2.30337433,
#         0.13148796,  1.84127518, -0.03507743, -0.96621682,  0.48788631,
#        -0.44579348, -0.54222595, -0.32790869, -1.41720149,  0.97097146,
#        -0.34924433, -0.18025448,  0.18802116,  0.39339178,  0.13456543,
#         2.69878048,  1.10008634,  1.43621099,  0.46521902,  0.12663738,
#        -0.71837119, -0.49331212,  0.99062294, -0.18907028,  0.50708895,
#        -2.18605535, -0.28585797,  0.26383958,  1.13010952, -0.8213304 ,
#         0.29871904,  0.78322665, -1.72266181,  0.92704851,  0.8251155 ,
#         1.21810056,  1.16579619,  0.53066372, -1.22363893,  1.38781738,
#        -0.31827612,  0.2685661 , -1.26625527, -0.05646536, -2.10318954,
#        -1.48946241,  1.68437238, -0.58743201,  1.25777732, -1.19019348,
#         0.42034052,  0.85931221,  0.03358263,  0.71093098,  0.42653819,
#         0.16803833,  0.95767756, -2.07154344, -0.1219148 ,  0.66572806])

# %% [markdown]
# ## Step 3: Generating the Scatterplot
# - Define x-axis as the index of the data
# - Define y-axis as the data itself
# - Provide labels for the title and x and y axes

# %%
plt.figure()
plt.scatter(range(len(data)), data)
plt.title('Scatter Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data)
plt.show()

# %% [markdown]
# ## Step 4: Generating a Histogram
# - Limit the number of bars to 10
# - Provide labels for the title and x and y axes

# %%
plt.figure()
plt.hist(data, bins=20)
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Step 5: Generating Subplots
# - Generate a scatterplot in the first half of the space
# - Provide labels for the title, x, and y axes
# - Generate a histogram in the second half of the space
# - Provide labels for the title and x and y axes

# %%
# Subplot
plt.figure()
plt.subplot(2, 1, 1)  
plt.scatter(range(len(data)), data)
plt.title('Scatter Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

plt.subplot(2,1,2)
plt.hist(data, bins = 5)
plt.title('Histogram Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ## Step 6: Generating a Line plot
# - Use the index of the data in the x-axis
# - Use the data on the y axis
# - Provide labels for the title and x and y axes

# %%
plt.figure()
plt.plot(range(len(data)), data)
plt.title('Line Plot')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# __Observations:__
#
# - For the generated data of random numbers, we have created scatter plots, subplots, histograms, and line plots.

# %%
import matplotlib.pyplot as plt
import numpy as np

fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
sales = [400, 350, 300, 450]

plt.bar(fruits, sales)
plt.title('Fruit Sales')
plt.xlabel('Fruits')
plt.ylabel('Sales')
plt.show()
