# %%
import pandas as pd
df = pd.read_csv('housing_data.csv')
df.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 1455      Reg         Lvl    AllPub  ...        0     No     No          No
# 1456      Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 1457      Reg         Lvl    AllPub  ...        0     No  GdPrv        Shed
# 1458      Reg         Lvl    AllPub  ...        0     No     No          No
# 1459      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
 
df.shape
# Out:
# (1460, 81)

# %%
df.info() # DataFrame info to check data types and non-null counts and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Length: 1460, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
df.isnull().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
df.isna().sum().unique() # Check for missing values in the DataFrame
# Out:
# array([   0, 1369,  872,    1,   81], dtype=int64)

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataframe = pd.read_csv('telecom.csv')
dataframe.head()
# Out:
#    caseid  age  gender  devicetype  locality  region  calls  sms  data  vas  \
# 0       1    2       1           1         0       2    303  102  1756   27
# 1       2    1       1           1         0       1    370   94  2048   13
# 2       3    0       1           1         1       0    425   95  2147   15
# 3       4    1       1           1         1       1    284   88  1784   23
# 4       5    2       1           0         1       1    419  102  2070   21
#
#    network  rcalls  rsms  seconds    amount
# 0       52      60    51    38755  1131.850
# 1       46      74    47    67635  1706.500
# 2       38      85    47    29123   857.885
# 3       52      56    44    25803   825.560
# 4       57      83    51    41156  1067.820

# %%
dataframe.tail()
# Out:
#      caseid  age  gender  devicetype  locality  region  calls  sms  data  vas  \
# 995      96    1       0           0         1       1    507  115  1969   14
# 996      97    1       1           1         1       3    277   97  1820   19
# 997      98    3       1           0         1       2     94  102  2470   16
# 998      99    2       0           1         1       1    545  106  2095   17
# 999     100    0       0           0         1       2    471  103  2078   18
#
#      network  rcalls  rsms  seconds    amount
# 995       41     101    57    44653  1260.535
# 996       50      55    48    26328   911.510
# 997       59      18    51    10594   401.030
# 998       45     109    53    46428  1536.485
# 999       47      94    51    62032  1657.740

# %%
dataframe.isna().sum() # Check for missing values in the DataFrame
# Out:
# caseid        0
# age           0
# gender        0
# devicetype    0
# locality      0
# region        0
# calls         0
# sms           0
# data          0
# vas           0
# network       0
# rcalls        0
# rsms          0
# seconds       0
# amount        0
# dtype: int64

# %%
dataframe.describe() # Get a summary of the DataFrame, including count, mean, std, min, 25%, 50%, 75%, and max values
# Out:
#             caseid          age       gender   devicetype    locality  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     50.500000     1.531000     0.595000     0.667000     0.61800
# std      28.880514     0.872812     0.491138     0.471522     0.48612
# min       1.000000     0.000000     0.000000     0.000000     0.00000
# 25%      25.750000     1.000000     0.000000     0.000000     0.00000
# 50%      50.500000     2.000000     1.000000     1.000000     1.00000
# 75%      75.250000     2.000000     1.000000     1.000000     1.00000
# max     100.000000     3.000000     1.000000     1.000000     1.00000
#
#             region        calls          sms         data          vas  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.510000   400.128000    99.379000  1996.288000    19.458000
# std       0.864087    99.802967     5.008037   252.092486     5.074247
# ...

# %%
dataframe.corr() # Get the correlation matrix of the DataFrame, showing the correlation between each pair of columns
# Out:
#               caseid       age    gender  devicetype  locality    region  \
# caseid      1.000000  0.025077  0.000953   -0.017531 -0.023885 -0.019053
# age         0.025077  1.000000  0.021145    0.026324 -0.021606 -0.031602
# gender      0.000953  0.021145  1.000000    0.052453  0.055720  0.029602
# devicetype -0.017531  0.026324  0.052453    1.000000  0.034037  0.048719
# locality   -0.023885 -0.021606  0.055720    0.034037  1.000000 -0.012344
# region     -0.019053 -0.031602  0.029602    0.048719 -0.012344  1.000000
# calls       0.010779  0.030912 -0.012215    0.013074 -0.012258  0.017547
# sms        -0.020136  0.012538  0.028282    0.007294 -0.004203 -0.013021
# data        0.054580  0.018202 -0.026279    0.018947 -0.041977 -0.057239
# vas        -0.032165  0.051939 -0.001008    0.055440 -0.015844  0.004205
# network     0.026352  0.042187  0.009278   -0.036179  0.006974  0.063264
# rcalls      0.011004  0.030328 -0.012111    0.013441 -0.012888  0.017589
# ...

# %%
dataframe.info() # Get information about the DataFrame, including the number of entries, column names, data types, and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   caseid      1000 non-null   int64
#  1   age         1000 non-null   int64
#  2   gender      1000 non-null   int64
#  3   devicetype  1000 non-null   int64
#  4   locality    1000 non-null   int64
#  5   region      1000 non-null   int64
#  6   calls       1000 non-null   int64
#  7   sms         1000 non-null   int64
#  8   data        1000 non-null   int64
#  9   vas         1000 non-null   int64
#  10  network     1000 non-null   int64
#  11  rcalls      1000 non-null   int64
#  12  rsms        1000 non-null   int64
#  13  seconds     1000 non-null   int64
#  14  amount      1000 non-null   float64
# dtypes: float64(1), int64(14)
# memory usage: 117.3 KB

# %%
dataframe.gender.value_counts() # Count the number of occurrences of each unique value in the
# Out:
# gender
# 1    595
# 0    405
# Name: count, dtype: int64

# %%
categories = ['Male', 'Female'] # Define
values = dataframe['gender'].value_counts()

# Create a bar chart
plt.bar(categories, values, color='orange', edgecolor='black', label=values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()
